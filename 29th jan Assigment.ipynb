# %% [raw]
# Q-1=Who developed python programming language?
#
# Python programming language was developed by Guido van Rossum in the late 1980s while he was working at the National Research Institute for Mathematics and Computer Science (CWI) in the Netherlands. It was first released in 1991 and has since become one of the most popular programming languages in the world.

# %% [raw]
# Q-2=Which type pf programming does python support?
#
# Python is a versatile programming language that supports a variety of programming paradigms, including:
#
# Procedural programming
# Object-oriented programming
# Functional programming
# Aspect-oriented programming
# Metaprogramming
# Pythons flexibility and ease of use make it a popular choice for a wide range of applications, from web development to scientific computing to data analysis and machine learning.

# %% [raw]
# Q-3=Is python case sensetive when dealing with identifiers?
# Yes, Python is case sensitive when it comes to identifiers such as variable names, function names, and class names. This means that identifiers with different capitalization are considered to be different and separate entities.
#
# For example, the following two variable names are not the same in Python:
#
# my_variable = 10
# My_Variable = 20
# Even though the names are very similar, the capitalization of the second variable is different, so Python treats them as separate identifiers.
#
# It's important to keep this in mind when writing Python code, to ensure that you use the correct capitalization when referring to identifiers throughout your program.

# %% [raw]
# Q-4=What is correct extension of the python file?
#
# The correct extension for a Python file is ".py". When you save a Python script, you should give it a filename with the ".py" extension to indicate that it contains Python code.
#
# For example, if you have a Python script that calculates the area of a rectangle, you might save it as "rectangle_area.py".
#
# The ".py" extension is used by Python to identify files that contain Python code, and it's also recognized by many text editors and integrated development environments (IDEs) that provide syntax highlighting, autocompletion, and other features for working with Python code.

# %% [raw]
# Q-5=is python code compilled or interpreted?
#
# Python code is interpreted, not compiled. When you run a Python program, the Python interpreter reads the source code of your program line by line and executes each line as it is encountered. This makes Python a dynamically typed, interpreted language.
#
# When you run a Python program, the interpreter checks each line of code for syntax errors and other issues, and then executes the code if everything is correct. This makes Python a very flexible language, as you can easily test and modify code on the fly without needing to go through a compilation step.
#
# There are tools available, such as PyInstaller and PyOxidizer, which allow you to package Python code as standalone executables, but even in these cases, the Python interpreter is still used to execute the code.

# %% [raw]
# Q-5=Name a few blocks of code used to give single line comment in python?
#
# In Python, you can add a single-line comment to your code by using the "#" character. Anything that appears after the "#" on a line is treated as a comment and is ignored by the Python interpreter. Here are a few examples:
#
# # This is a comment
# x = 10  # This is also a comment
# You can also use a single-line string literal to add a comment, although this is less common. Here's an example:
#
# " This is a comment on its own line "
# It's important to add comments to your code to make it more readable and understandable, especially if you're working on a team or sharing your code with others. Comments can explain what the code does, why it's there, and how it works, and can save a lot of time and confusion down the line.

# %% [raw]
# Q-6=Name a few blocks of code used to define in python language?
# In Python, you can define various things using different blocks of code. Here are a few examples:
#
# Defining a function:
# def my_function(arg1, arg2):
#     # function body goes here
#     return result
#
# Defining a class:
# class MyClass:
#     def __init__(self, arg1, arg2):
#         # constructor body goes here
#     def my_method(self, arg):
#         # method body goes here
#
# Defining a conditional block using if-elif-else:
# if condition1:
#     # code block 1
# elif condition2:
#     # code block 2
# else:
#     # code block 3
#
# Defining a loop using for or while:
# for i in range(10):
#     # code block to repeat goes here
# while condition:
#     # code block to repeat goes here
# These are just a few examples of how you can use blocks of code to define different structures in Python. There are many other structures and statements in Python that use similar blocks of code to define their behavior.

# %% [raw]
# Q-7=State a character used to give single line comments in python
# In Python, the character used to indicate a single-line comment is the hash symbol "#". Anything that appears after the hash symbol on a line is treated as a comment and is ignored by the Python interpreter.
#
# Here's an example of a single-line comment in Python:
#
# # This is a single-line comment
# You can also use the hash symbol to add comments at the end of a line of code:
#
# x = 10  # This is a comment
# Adding comments to your code is important to make it more readable and understandable, especially if you're working on a team or sharing your code with others. Comments can explain what the code does, why it's there, and how it works, and can save a lot of time and confusion down the line.

# %% [raw]
# Q-8=Mention functions which can help us to find us to find the version of python that we are currently working on?
#
# In Python, you can use the sys module to find the version of Python that you are currently working on. Here are a few functions that you can use:
# sys.version: This returns a string containing the version number of the Python interpreter, as well as information about the build and the platform.
# sys.version_info: This returns a tuple containing the major, minor, and micro version numbers of the Python interpreter.
#
# Here's an example of how you can use these functions to find the Python version:
# import sys
#
# # Get the Python version as a string
# print("Python version:", sys.version)
#
# # Get the Python version as a tuple
# print("Python version info:", sys.version_info)
# When you run this code, you'll see the version of Python that you're currently working on printed to the console. For example, the output might look something like this:
#
#
# Python version: 3.9.0 (default, Oct  6 2020, 00:00:00) [GCC 10.2.0]
# Python version info: sys.version_info(major=3, minor=9, micro=0, releaselevel='final', serial=0)
# These functions can be useful when you need to check the Python version that you're working with, especially if you're working on a system with multiple versions of Python installed.

# %% [raw]
# 10. What does pip stand for python?
# "Pip" stands for "Pip Installs Packages". It is a package management system used to install and manage software packages written in Python. With pip, you can easily install and manage Python packages from the Python Package Index (PyPI) as well as other repositories.
#
# Here are some common pip commands:
#
# pip install package_name: This command installs the specified package and any dependencies that it requires.
#
# pip uninstall package_name: This command uninstalls the specified package.
#
# pip list: This command lists all the packages that are installed on your system.
#
# pip freeze: This command lists all the packages that are installed on your system, along with their version numbers, in a format that can be used to create a requirements file.
#
# Pip is a widely used tool in the Python community, and it makes it easy to install and manage third-party packages and libraries for your Python projects.
#
#
#
#
#
# Q-11= Mention a few built-in functions in python?
# Python comes with a large number of built-in functions that are available for use in any Python program. Here are some examples of commonly used built-in functions in Python:
#
# print(): This function is used to output text to the console or terminal.
#
# len(): This function returns the number of items in a sequence (such as a string, list, or tuple).
#
# type(): This function returns the type of a variable or value.
#
# range(): This function creates a sequence of numbers from a starting point to an ending point, with an optional step size.
#
# int(), float(), and str(): These functions convert values to integers, floating-point numbers, and strings, respectively.
#
# input(): This function is used to get input from the user via the console or terminal.
#
# sum(): This function calculates the sum of all the values in a list or iterable.
#
# min() and max(): These functions return the minimum and maximum values in a list or iterable.
#
# abs(): This function returns the absolute value of a number.
#
# sorted(): This function returns a sorted version of a list or iterable.
#
# These are just a few examples of the many built-in functions available in Python. By using built-in functions, you can save time and simplify your code, making it easier to read and maintain.
#
#
#
#
#
# Q-12= What is the maximum possible length of an identifier in Python?
# In Python, the maximum length of an identifier is not specified or limited by the language itself. However, it is generally recommended to keep identifiers short and descriptive, to make your code more readable and maintainable.
#
# Technically, an identifier can be as long as you like, as long as it follows the rules for identifier naming in Python. An identifier can only contain letters (both uppercase and lowercase), digits, and underscores (_), and it must begin with a letter or an underscore (but not a digit). Identifiers are case-sensitive, so my_variable and My_Variable are two different identifiers.
#
# Here are some examples of valid identifiers in Python:
#
# my_variable = 42
# hello_world = "Hello, World!"
# __private_var = "I am a private variable"
# In general, it's a good practice to keep your identifiers short and meaningful, so that your code is easy to read and understand. PEP 8, the official style guide for Python code, recommends using lowercase letters for variable and function names, and separating words with underscores for readability.

# %% [raw]
# Q-13= What are the benefits of using Python?
# There are many benefits of using Python as a programming language. Here are some of the main advantages:
#
# Easy to learn and use: Python has a simple and easy-to-learn syntax that makes it an ideal language for beginners. Its syntax is designed to be easy to read and write, which makes it faster to develop code and easier to maintain.
#
# Versatile: Python is a versatile language that can be used for a wide range of applications, from web development to data analysis, machine learning, and artificial intelligence. It is also used in scientific computing, gaming, and many other fields.
#
# Large standard library: Python has a large standard library that provides many useful modules and functions for common programming tasks, such as file I/O, string manipulation, and networking.
#
# Third-party libraries: In addition to the standard library, Python has a vast ecosystem of third-party libraries and tools that can be used to extend its functionality. Some popular libraries include NumPy, Pandas, Matplotlib, and TensorFlow.
#
# Cross-platform compatibility: Python is a cross-platform language, which means that code written on one platform (such as Windows) can be easily ported to another platform (such as Linux or macOS).
#
# Open-source: Python is an open-source language, which means that its source code is freely available and can be modified and redistributed by anyone. This has led to a large and active community of developers who contribute to the language and its ecosystem.
#
# Productivity: Python is a high-level language that allows you to write code more quickly and with fewer lines than other languages. This can make you more productive and allow you to focus on solving problems rather than worrying about low-level details.
#
# Overall, Python is a powerful and versatile language that is widely used in many fields. Its ease of use, large standard library, and active community make it an attractive choice for developers of all levels.
#
#
#
#
#
# Q-14= How is memory managed in Python?
# Memory management in Python is handled automatically by the Python runtime environment. Python uses a technique called reference counting to manage memory allocation and deallocation.
#
# Reference counting works by keeping track of the number of references to an object in memory. Each time a new reference is created to an object, the reference count for that object is incremented. When a reference is removed or goes out of scope, the reference count for the object is decremented. When the reference count for an object reaches zero, it means that the object is no longer being used and its memory can be deallocated.
#
# Python also has a built-in garbage collector that runs periodically to clean up objects that are no longer being used. The garbage collector identifies objects that have a reference count of zero and frees up their memory.
#
# In addition to reference counting and garbage collection, Python also supports a technique called "memory pooling". Memory pooling involves pre-allocating chunks of memory and reusing them instead of repeatedly allocating and deallocating memory. This can help to reduce memory fragmentation and improve performance.
#
# Overall, memory management in Python is transparent to the programmer and is handled automatically by the runtime environment. This allows developers to focus on writing code without having to worry about low-level memory management details.
#
#
#
#
#
# Q-15= How to install Python on Windows and set path variables? 16. Is indentation required in python?
# How to install Python on Windows and set path variables?
# To install Python on Windows and set the path variables, follow these steps:
#
# Download the latest version of Python from the official website: https://www.python.org/downloads/windows/
#
# Run the installer and follow the on-screen instructions to install Python.
#
# During the installation process, make sure to select the option to add Python to your system PATH variable.
#
# After the installation is complete, open a command prompt and type "python" to confirm that Python is installed and the path variables are set correctly.
#
# You can also check the version of Python installed by typing "python --version" in the command prompt.
#
# Is indentation required in python?
#
# Yes, indentation is required in Python. Unlike other programming languages that use curly braces or keywords to define blocks of code, Python uses indentation to define the scope of a block. Indentation is used to group statements together into a single block of code that is executed together.
#
# The standard convention in Python is to use four spaces for indentation. Using tabs or a different number of spaces for indentation can result in errors or unexpected behavior.
#
# For example, consider the following code snippet:
#
# if x > 0:
#     print("x is positive")
# else:
#     print("x is non-positive")
# In this example, the "if" and "else" blocks are defined using indentation. The "print" statements are indented four spaces to indicate that they are part of the "if" or "else" block. If the indentation is not used correctly, the code will not work as expected.
